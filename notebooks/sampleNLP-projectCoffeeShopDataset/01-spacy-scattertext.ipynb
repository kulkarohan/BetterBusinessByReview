# %%
import pandas as pd
import scattertext as st
import spacy
from pprint import pprint
from collections import Counter
import re
from spacy.tokenizer import Tokenizer
from nltk.stem import PorterStemmer

shops = pd.read_csv('C:\\Users\\lilyx\\DS-Unit-4-Sprint-1-NLP\\module1-text-data\\data\\yelp_coffeeshop_review_data.csv')
shops.sample(6)
# Out:
#                   coffee_shop_name  \
# 2580       Flightpath Coffeehouse
# 6977              My Sweet Austin
# 3332                  Jo’s Coffee
# 7453              Hot Mama’s Cafe
# 3900  Lola Savannah Coffee Lounge
# 891                 Legend Coffee
#
#                                        full_review_text        star_rating
# 2580   3/11/2014 26 check-ins Flightpath has quickly...   4.0 star rating
# 6977   2/27/2016 All I can say is PERFECTION! We sho...   5.0 star rating
# 3332   10/16/2015 1 check-in Yummy yum yum! :)  I ha...   5.0 star rating
# 7453   3/9/2013 1 check-in Underneath the sign for H...   2.0 star rating
# 3900   1/25/2016 Out of the 45+ coffee houses that I...   5.0 star rating
# 891    7/1/2015 I love a good coffee so came over to...   5.0 star rating

# %%
#to remove dates at the beginning of string, split the string into a list of words, then indexing the second to last words
splitty = lambda x: x['full_review_text'].split()[1:]
shops['full_review_text'] = shops.apply(splitty, axis=1)

shops.sample(3)
# Out:
#              coffee_shop_name  \
# 3566                  Patika
# 3600                  Cenote
# 4755  Venezia Italian Gelato
#
#                                        full_review_text        star_rating
# 3566  [So, my, coffee, standards, are, high, to, sta...   5.0 star rating
# 3600  [Cenote, has, been, my, go-to, cafe, since, I,...   3.0 star rating
# 4755  [Simply, awesome., This, is, the, place, for, ...   5.0 star rating

# %%
#join list of words back together
jointty = lambda x: ' '.join(map(lambda x: str(x), x['full_review_text']))
shops['full_review_text'] = shops.apply(jointty, axis=1)
# shops['full_review_text'] = ','.join([str(x) for x in shops['full_review_text']])
shops.sample(3)
# Out:
#                   coffee_shop_name  \
# 6378  Strange Brew, Austin Coffee
# 6023              La Tazza Fresca
# 5513          Radio Coffee & Beer
#
#                                        full_review_text        star_rating
# 6378  Decent coffee and easy laid back atmosphere. I...   3.0 star rating
# 6023  Pretty good coffee and really great sandwiches...   4.0 star rating
# 5513  They have a great selection of beer and have a...   2.0 star rating

# %%
#lowercasing all words in review
lowercase = lambda x: str.lower(x['full_review_text'])
shops['full_review_text'] = shops.apply(lowercase, axis=1)
# shops['full_review_text'] = ','.join([str(x) for x in shops['full_review_text']])
shops.sample(3)
# Out:
#      coffee_shop_name                                   full_review_text  \
# 1997    Epoch Coffee   10 check-ins listed in coffee thursday this pl...
# 5716  Trianon Coffee   3 check-ins my monday morning stop for fresh r...
# 5206            TOMS   2 check-ins i finally was able to check this p...
#
#             star_rating
# 1997   4.0 star rating
# 5716   3.0 star rating
# 5206   4.0 star rating

# %%
#calling spacy's default stop words and adding some manually
nlp = spacy.load("en_core_web_md")
tokenizer = Tokenizer(nlp.vocab)#breaks text, it creates character indexes instead of splitting words up

STOP_WORDS = nlp.Defaults.stop_words.union(['check-in','=','= =','male','u','want', 'u want', 'cuz','him','check-in','him',"i've", 'deaf','on', 'her','told','told him','ins', '1 check','I', 'i"m', 'i', ' ', 'it', "it's", 'it.','they','coffee','place','they', 'the', 'this','its', 'l','-','they','this','don"t','the ', ' the', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.',','])

# STOP_WORDS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68bf35c89f25> in <module>
#       1 #calling spacy's default stop words and adding some manually
# ----> 2 nlp = spacy.load("en_core_web_md")
#       3 tokenizer = Tokenizer(nlp.vocab)#breaks text, it creates character indexes instead of splitting words up
#       4
#       5 STOP_WORDS = nlp.Defaults.stop_words.union(['check-in','=','= =','male','u','want', 'u want', 'cuz','him','check-in','him',"i've", 'deaf','on', 'her','told','told him','ins', '1 check','I', 'i"m', 'i', ' ', 'it', "it's", 'it.','they','coffee','place','they', 'the', 'this','its', 'l','-','they','this','don"t','the ', ' the', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.',','])
#
# NameError: name 'spacy' is not defined

# %%
#create tokens based on stop words
tokens = []

for doc in tokenizer.pipe(shops['full_review_text'], batch_size=800):
    
    doc_tokens = []
    
    for token in doc: 
        if token.text not in STOP_WORDS:
            doc_tokens.append(token.text.lower())
   
    tokens.append(doc_tokens)
    
shops['tokens'] = tokens

# %%
shops.sample(3)
# Out:
#                      coffee_shop_name  \
# 1138  The Factory - Cafe With a Soul
# 5357                Cuvée Coffee Bar
# 5242                     Genuine Joe
#
#                                        full_review_text        star_rating  \
# 1138  this place is really nice. they have done a gr...   5.0 star rating
# 5357  you can find me at cuvee almost every other mo...   5.0 star rating
# 5242  room nice. plain coffee meh. they have intrigu...   4.0 star rating
#
#                                                  tokens
# 1138  [nice., great, job..., type, spend, hours, in....
# 5357  [find, cuvee, morning., great, baristas, aweso...
# 5242  [room, nice., plain, meh., intriguing, over-th...

# %%
#join tokens back together for use
jointty = lambda x: ' '.join(map(lambda x: str(x), x['tokens']))
shops['joined_tokens'] = shops.apply(jointty, axis=1)
shops.sample(3)
# Out:
#            coffee_shop_name  \
# 4958  Once Over Coffee Bar
# 6819                   Teo
# 6871                   Teo
#
#                                        full_review_text        star_rating  \
# 4958  i like the location, and i like some of the pe...   3.0 star rating
# 6819  2 check-ins the gelato is on the pricy side co...   2.0 star rating
# 6871  11 check-ins best espresso in town! get the do...   5.0 star rating
#
#                                                  tokens  \
# 4958  [like, location,, like, people, work, there......
# 6819  [check-ins, gelato, pricy, compares, gelato, p...
# 6871  [11, check-ins, best, espresso, town!, double,...
#
#                                           joined_tokens
# 4958  like location, like people work there... like ...
# 6819  check-ins gelato pricy compares gelato places ...
# 6871  11 check-ins best espresso town! double machia...

# %%
#start of scattertext library magic
corpus = st.CorpusFromPandas(shops, 
                             category_col='star_rating', 
                             text_col='joined_tokens',
                             nlp=nlp).build()

# %%
#getting a list of words correlated with high rating score
term_freq_df = corpus.get_term_freq_df()
term_freq_df['highratingscore'] = corpus.get_scaled_f_scores(' 5.0 star rating ')
pprint(list(term_freq_df.sort_values(by='highratingscore', ascending=False).index[:10]))
# Out:
# ['= =',
#  'best gelato',
#  'venezia',
#  'coast',
#  "anderson 's",
#  'italy',
#  'love love',
#  'incredible',
#  'pound',
#  'sara']

# %%
#getting a list of words correlated with low rating score
term_freq_df['poorratingscore'] = corpus.get_scaled_f_scores(' 1.0 star rating ')
pprint(list(term_freq_df.sort_values(by='poorratingscore', ascending=False).index[:10]))
# Out:
# ['particularly fabulous',
#  'milk splendas',
#  'understand business',
#  'stars cuz',
#  'splendas',
#  'cancelled order',
#  'policies',
#  'understanding',
#  'cancelled',
#  'male']

# %%
#creating a dataframe ranking the words correlated with poorest ratings
term_freq_df.sort_values(by= 'poorratingscore', ascending = False)
# Out:
#                         5.0 star rating  freq   4.0 star rating  freq  \
# term
# particularly fabulous                       0                       0
# milk splendas                               0                       0
# understand business                         0                       0
# stars cuz                                   0                       0
# splendas                                    0                       0
# cancelled order                             0                       0
# policies                                    1                       0
# understanding                               1                       0
# cancelled                                   0                       0
# male                                        2                       3
# haired                                      1                       1
# philz                                       5                       1
# shell shocked                               0                       0
# 's website                                  0                       0
# u want                                      0                       0
# rudest                                      0                       0
# matt                                        5                       2
# overpriced food                             0                       0
# large drink                                 1                       0
# rudely                                      0                       0
# paying customers                            0                       0
# stay away                                   1                       1
# mozarts                                     2                       0
# inconvenience                               1                       0
# horribly                                    1                       0
# shocked                                     3                       3
# angus                                       3                       1
# asked wanted                                1                       2
# tipped                                      1                       0
# requested                                   2                       1
# ...                                       ...                     ...
# couches                                    56                      52
# folks                                      67                      45
# moon milk                                  86                      37
# cortado                                    70                      37
# modern                                     61                      49
# beers                                      74                      51
# boba                                       54                      65
# strawberry                                 76                      44
# heart                                      89                      41
# roasted                                    82                      39
# milk tea                                   57                      67
# book                                       79                      58
# halcyon                                    54                      61
# baked goods                                62                      66
# live music                                 82                      57
# waffles                                    97                      55
# cinnamon                                   72                      77
# creamy                                    103                      63
# goods                                      81                      71
# located                                    75                      89
# play                                       99                      72
# ins listed                                 83                      91
# ambiance                                   80                      74
# waffle                                    117                      56
# smooth                                    133                      63
# unique                                    129                      91
# variety                                   133                      99
# art                                       158                      72
# fan                                       116                     124
# outlets                                   101                     141
#
#                         2.0 star rating  freq   3.0 star rating  freq  \
# term
# particularly fabulous                       0                       0
# milk splendas                               0                       0
# understand business                         0                       0
# stars cuz                                   0                       0
# splendas                                    0                       1
# cancelled order                             0                       1
# policies                                    0                       0
# understanding                               0                       2
# cancelled                                   1                       1
# male                                        1                       0
# haired                                      1                       1
# philz                                       0                       0
# shell shocked                               0                       0
# 's website                                  0                       0
# u want                                      0                       0
# rudest                                      0                       0
# matt                                        0                       0
# overpriced food                             0                       1
# large drink                                 0                       0
# rudely                                      2                       0
# paying customers                            0                       2
# stay away                                   0                       0
# mozarts                                     0                       0
# inconvenience                               1                       4
# horribly                                    1                       1
# shocked                                     0                       1
# angus                                       0                       0
# asked wanted                                3                       0
# tipped                                      1                       4
# requested                                   1                       2
# ...                                       ...                     ...
# couches                                     1                      15
# folks                                       6                       8
# moon milk                                   2                       2
# cortado                                     9                      16
# modern                                      9                      15
# beers                                       1                      10
# boba                                        8                      10
# strawberry                                  5                      13
# heart                                       2                       8
# roasted                                    11                       9
# milk tea                                   12                       7
# book                                        1                      10
# halcyon                                    15                      19
# baked goods                                 7                      20
# live music                                  8                      15
# waffles                                     1                      10
# cinnamon                                   13                      11
# creamy                                      3                      14
# goods                                       9                      23
# located                                     7                      16
# play                                        3                      14
# ins listed                                  2                      17
# ambiance                                   10                      34
# waffle                                      4                      21
# smooth                                      5                      15
# unique                                      1                      19
# variety                                     4                      14
# art                                        19                      10
# fan                                        17                      18
# outlets                                     8                      30
#
#                         1.0 star rating  freq  highratingscore  \
# term
# particularly fabulous                       8         0.347828
# milk splendas                               6         0.386662
# understand business                         6         0.386662
# stars cuz                                   6         0.386662
# splendas                                    6         0.367032
# cancelled order                             6         0.367032
# policies                                    6         0.399203
# understanding                               7         0.338671
# cancelled                                   6         0.347828
# male                                       12         0.227176
# haired                                      6         0.338671
# philz                                       8         0.380910
# shell shocked                               5         0.406681
# 's website                                  5         0.406681
# u want                                      5         0.406681
# rudest                                      5         0.406681
# matt                                        9         0.339228
# overpriced food                             5         0.386662
# large drink                                 5         0.421037
# rudely                                      5         0.367032
# paying customers                            5         0.367032
# stay away                                   5         0.399203
# mozarts                                     5         0.436573
# inconvenience                               7         0.284014
# horribly                                    5         0.378296
# shocked                                     8         0.301590
# angus                                       5         0.426579
# asked wanted                                6         0.301615
# tipped                                      6         0.301615
# requested                                   6         0.329453
# ...                                       ...              ...
# couches                                     0         0.858684
# folks                                       0         0.894037
# moon milk                                   0         0.942432
# cortado                                     0         0.893471
# modern                                      0         0.860565
# beers                                       0         0.898897
# boba                                        0         0.116698
# strawberry                                  0         0.901426
# heart                                       0         0.930443
# roasted                                     0         0.912688
# milk tea                                    0         0.118879
# book                                        0         0.894861
# halcyon                                     0         0.101663
# baked goods                                 0         0.119565
# live music                                  0         0.883559
# waffles                                     0         0.917359
# cinnamon                                    0         0.127775
# creamy                                      0         0.905956
# goods                                       0         0.853342
# located                                     0         0.120096
# play                                        0         0.891992
# ins listed                                  0         0.135061
# ambiance                                    0         0.121584
# waffle                                      0         0.915932
# smooth                                      0         0.924182
# unique                                      0         0.896325
# variety                                     0         0.894154
# art                                         0         0.922334
# fan                                         0         0.130707
# outlets                                     0         0.100889
#
#                        poorratingscore
# term
# particularly fabulous     1.000000e+00
# milk splendas             9.997953e-01
# understand business       9.997953e-01
# stars cuz                 9.997953e-01
# splendas                  9.997839e-01
# cancelled order           9.997839e-01
# policies                  9.997839e-01
# understanding             9.997676e-01
# cancelled                 9.997044e-01
# male                      9.996268e-01
# haired                    9.987572e-01
# philz                     9.984381e-01
# shell shocked             9.982367e-01
# 's website                9.982367e-01
# u want                    9.982367e-01
# rudest                    9.982367e-01
# matt                      9.982328e-01
# overpriced food           9.982182e-01
# large drink               9.982182e-01
# rudely                    9.980672e-01
# paying customers          9.980672e-01
# stay away                 9.980672e-01
# mozarts                   9.980672e-01
# inconvenience             9.975350e-01
# horribly                  9.975224e-01
# shocked                   9.973786e-01
# angus                     9.962965e-01
# asked wanted              9.957711e-01
# tipped                    9.957711e-01
# requested                 9.957711e-01
# ...                                ...
# couches                   1.901420e-04
# folks                     1.528022e-04
# moon milk                 1.368169e-04
# cortado                   7.780786e-05
# modern                    6.173923e-05
# beers                     4.883326e-05
# boba                      4.337842e-05
# strawberry                3.850217e-05
# heart                     3.025993e-05
# roasted                   2.679408e-05
# milk tea                  2.095745e-05
# book                      1.118150e-05
# halcyon                   9.837560e-06
# baked goods               4.486231e-06
# live music                1.730323e-06
# waffles                   1.505280e-06
# cinnamon                  3.574368e-07
# creamy                    7.826452e-08
# goods                     6.693606e-08
# located                   4.167015e-08
# play                      3.552271e-08
# ins listed                1.579802e-08
# ambiance                  6.884024e-09
# waffle                    6.884024e-09
# smooth                    2.921516e-10
# unique                    2.860101e-12
# variety                   3.613221e-13
# art                       5.206946e-14
# fan                       1.165734e-15
# outlets                   0.000000e+00
#
# [202203 rows x 7 columns]

# %%
html = st.produce_scattertext_explorer(corpus,
         category=' 1.0 star rating ',
         category_name='Poor Yelp Rating',
         not_category_name='High Yelp Rating',
         width_in_pixels=1000,
         metadata=shops['coffee_shop_name'])
open("Yelp-CoffeeShop-Visualization.html", 'wb').write(html.encode('utf-8'))
# Out:
# 4840268
